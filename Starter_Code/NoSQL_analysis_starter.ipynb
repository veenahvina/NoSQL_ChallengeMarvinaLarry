# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review the collections in our new database
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('6522b3047ac491058387dd69'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.195625, 'latitude': 51.083812}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
print("Number of documents with Hygiene equal to 20:", establishments.count_documents(query))

# Display the first document in the results using pprint
establishments.find_one(query)
# Out:
# Number of documents with Hygiene equal to 20: 123
# {'_id': ObjectId('6522b3047ac491058387f89d'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.769705},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/110681'}]}

# %%
# Convert the result to a Pandas DataFrame
results = list(establishments.find({}))
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of documents in the DataFrame:", len(results))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Number of documents in the DataFrame: 116359
#                         _id     FHRSID  ChangesByServerID  \
# 0  6522b3047ac491058387dd69  1043695.0                0.0
# 1  6522b3047ac491058387dd6b   647177.0                0.0
# 2  6522b3047ac491058387dd6d   289353.0                0.0
# 3  6522b3047ac491058387dd73   344689.0                0.0
# 4  6522b3047ac491058387dd74   987206.0                0.0
# 5  6522b3047ac491058387dd76   289560.0                0.0
# 6  6522b3047ac491058387dd77   894592.0                0.0
# 7  6522b3047ac491058387dd78   805702.0                0.0
# 8  6522b3047ac491058387dd79   289352.0                0.0
# 9  6522b3047ac491058387dd7a  1046418.0                0.0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# 2             PI/000002468  St Marys COE (aided) Primary School
# 3             PI/000002095             Folkestone Trawlers Shop
# 4             PI/000075655                     The Ships Galley
# 5             PI/000039927                              Mariner
# 6             PI/000074396                               Docker
# 7             PI/000073219             Dr Legumes - Harbour Arm
# 8             PI/000002460                             The Ship
# 9             PI/000076426                    Custom Folkestone
#
#                 BusinessType BusinessTypeID  \
# 0    Restaurant/Cafe/Canteen              1
# 1          Pub/bar/nightclub           7843
# 2  School/college/university           7845
# 3          Retailers - other           4613
# 4          Pub/bar/nightclub           7843
# 5          Pub/bar/nightclub           7843
# 6          Retailers - other           4613
# 7    Restaurant/Cafe/Canteen              1
# 8          Pub/bar/nightclub           7843
# 9    Restaurant/Cafe/Canteen              1
#
#                                 AddressLine1           AddressLine2  \
# 0                        East Cliff Pavilion          Wear Bay Road
# 1                              Wear Bay Road             Folkestone
# 2  St Marys Church Of England Primary School            Warren Road
# 3                                1 The Stade             Folkestone
# 4                                   The Ship           23 The Stade
# 5                               16 The Stade             Folkestone
# 6                         Folkestone Harbour  Harbour Approach Road
# 7                         Folkestone Harbour  Harbour Approach Road
# 8                               23 The Stade             Folkestone
# 9                         Folkestone Harbour  Harbour Approach Road
#
#   AddressLine3  ...               LocalAuthorityWebSite  \
# 0   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 1         Kent  ...  http://www.folkestone-hythe.gov.uk
# 2   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 3         Kent  ...  http://www.folkestone-hythe.gov.uk
# 4   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 5         Kent  ...  http://www.folkestone-hythe.gov.uk
# 6   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 7   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 8         Kent  ...  http://www.folkestone-hythe.gov.uk
# 9   Folkestone  ...  http://www.folkestone-hythe.gov.uk
#
#          LocalAuthorityEmailAddress  \
# 0  foodteam@folkestone-hythe.gov.uk
# 1  foodteam@folkestone-hythe.gov.uk
# 2  foodteam@folkestone-hythe.gov.uk
# 3  foodteam@folkestone-hythe.gov.uk
# 4  foodteam@folkestone-hythe.gov.uk
# 5  foodteam@folkestone-hythe.gov.uk
# 6  foodteam@folkestone-hythe.gov.uk
# 7  foodteam@folkestone-hythe.gov.uk
# 8  foodteam@folkestone-hythe.gov.uk
# 9  foodteam@folkestone-hythe.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 1.195625, 'latitude': 51.083812}
# 1     {'longitude': 1.196408, 'latitude': 51.086058}
# 2     {'longitude': 1.194762, 'latitude': 51.085797}
# 3      {'longitude': 1.188537, 'latitude': 51.08084}
# 4      {'longitude': 1.188537, 'latitude': 51.08084}
# 5      {'longitude': 1.188537, 'latitude': 51.08084}
# 6  {'longitude': 1.18590330311705, 'latitude': 51...
# 7  {'longitude': 1.18590330311705, 'latitude': 51...
# 8      {'longitude': 1.188537, 'latitude': 51.08084}
# 9  {'longitude': 1.18590330311705, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4591.765489            False
# 1  4591.821311            False
# 2  4591.871474            False
# 3  4591.912145            False
# 4  4591.912145            False
# 5  4591.912145            False
# 6  4591.914705            False
# 7  4591.914705            False
# 8  4591.912145            False
# 9  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {'LocalAuthorityName': "London"},{"RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
print("Number of documents in the result:", establishments.count_documents(query2))

# Display the first document in the results using pprint
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[66], line 5
#       2 query2 = {'LocalAuthorityName': "London"},{"RatingValue": {"$gte": 4}}
#       4 # Use count_documents to display the number of documents in the result
# ----> 5 print("Number of documents in the result:", establishments.count_documents(query2))
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:1853, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    1850         return 0
#    1851     return result["n"]
# -> 1853 return self._retryable_non_cursor_read(_cmd, session)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:1859, in Collection._retryable_non_cursor_read(self, func, session)
#    1857 client = self.__database.client
#    1858 with client._tmp_session(session) as s:
# -> 1859     return client._retryable_read(func, self._read_preference_for(s), s)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/_csot.py:106, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     104         with _TimeoutContext(timeout):
#     105             return func(self, *args, **kwargs)
# --> 106 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/mongo_client.py:1465, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1463             assert last_error is not None
#    1464             raise last_error
# -> 1465         return func(session, server, sock_info, read_pref)
#    1466 except ServerSelectionTimeoutError:
#    1467     if retrying:
#    1468         # The application may think the write was never attempted
#    1469         # if we raise ServerSelectionTimeoutError on the retry
#    1470         # attempt. Raise the original exception instead.
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:1848, in Collection.count_documents.<locals>._cmd(session, server, sock_info, read_preference)
#    1847 def _cmd(session, server, sock_info, read_preference):
# -> 1848     result = self._aggregate_one_result(sock_info, read_preference, cmd, collation, session)
#    1849     if not result:
#    1850         return 0
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:1714, in Collection._aggregate_one_result(self, sock_info, read_preference, cmd, collation, session)
#    1712 def _aggregate_one_result(self, sock_info, read_preference, cmd, collation, session):
#    1713     """Internal helper to run an aggregate that returns a single result."""
# -> 1714     result = self._command(
#    1715         sock_info,
#    1716         cmd,
#    1717         read_preference,
#    1718         allowable_errors=[26],  # Ignore NamespaceNotFound.
#    1719         codec_options=self.__write_response_codec_options,
#    1720         read_concern=self.read_concern,
#    1721         collation=collation,
#    1722         session=session,
#    1723     )
#    1724     # cursor will not be present for NamespaceNotFound errors.
#    1725     if "cursor" not in result:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:293, in Collection._command(self, sock_info, command, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     266 """Internal command helper.
#     267
#     268 :Parameters:
#    (...)
#     290   The result document.
#     291 """
#     292 with self.__database.client._tmp_session(session) as s:
# --> 293     return sock_info.command(
#     294         self.__database.name,
#     295         command,
#     296         read_preference or self._read_preference_for(session),
#     297         codec_options or self.codec_options,
#     298         check,
#     299         allowable_errors,
#     300         read_concern=read_concern,
#     301         write_concern=write_concern,
#     302         parse_write_concern_error=True,
#     303         collation=collation,
#     304         session=s,
#     305         client=self.__database.client,
#     306         retryable_write=retryable_write,
#     307         user_fields=user_fields,
#     308     )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/helpers.py:279, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     276 from pymongo.pool import SocketInfo
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 except OperationFailure as exc:
#     281     if no_reauth:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/pool.py:879, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     877     self._raise_if_not_writable(unacknowledged)
#     878 try:
# --> 879     return command(
#     880         self,
#     881         dbname,
#     882         spec,
#     883         self.is_mongos,
#     884         read_preference,
#     885         codec_options,
#     886         session,
#     887         client,
#     888         check,
#     889         allowable_errors,
#     890         self.address,
#     891         listeners,
#     892         self.max_bson_size,
#     893         read_concern,
#     894         parse_write_concern_error=parse_write_concern_error,
#     895         collation=collation,
#     896         compression_ctx=self.compression_context,
#     897         use_op_msg=self.op_msg_enabled,
#     898         unacknowledged=unacknowledged,
#     899         user_fields=user_fields,
#     900         exhaust_allowed=exhaust_allowed,
#     901         write_concern=write_concern,
#     902     )
#     903 except (OperationFailure, NotPrimaryError):
#     904     raise
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/network.py:166, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164             client._process_response(response_doc, session)
#     165         if check:
# --> 166             helpers._check_command_response(
#     167                 response_doc,
#     168                 sock_info.max_wire_version,
#     169                 allowable_errors,
#     170                 parse_write_concern_error=parse_write_concern_error,
#     171             )
#     172 except Exception as exc:
#     173     if publish:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/helpers.py:194, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     191 elif code == 43:
#     192     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 194 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: the match filter must be an expression in an object, full error: {'ok': 0.0, 'errmsg': 'the match filter must be an expression in an object', 'code': 15959, 'codeName': 'Location15959'}

# %%
# Convert the result to a Pandas DataFrame
results2 = list(establishments.find({}))
result2_df = pd.DataFrame(results2)

# Display the number of rows in the DataFrame
print("Number of documents in the DataFrame:", len(results))

# Display the first 10 rows of the DataFrame
result2_df.head(10)

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
